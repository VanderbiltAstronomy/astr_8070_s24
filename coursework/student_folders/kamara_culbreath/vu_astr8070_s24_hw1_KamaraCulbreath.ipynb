# %% [markdown]
# ### ASTR 8070: Astrostatistics
# ***S. R. Taylor***
# ___
#
# # Homework 1
# ### Due: By class time on Jan 16th
# ---

# %% [markdown]
# ## Problem 1
#
# Practice your git and GitHub skills by submitting this homework via GitHub.  You can skip Steps 1-4 if you have already completed the in-class work of Lecture 1.  Steps 5-11 are the new steps.
#
# 1) Navigate to https://github.com/VanderbiltAstronomy/astr_8070_s24 on your browser. **Don't clone this!** Instead, look to the rop right of the page for an option to fork the repository. Do this now. This will make a copy of the class repository for your own personal use.
#
# 2) Now that you have a fork of the repository, clone it to your machine.
#
#     $ git clone https://github.com/YOUR_USERNAME/astr_8070_s24
#
# 3) Add the original `VanderbiltAstronomy` repository as an `upstream` repository to your fork. First, list the current configured remote repository for your fork with:
#
#     $ git remote -v
#
# Now, add the `VanderbiltAstronomy` repo as an upstream:
#
#     $ git remote add upstream https://github.com/VanderbiltAstronomy/astr_8070_s24
#
# Verify that the new repository shows as an `upstream` by running `git remote -v` again.
#
# 4) Get used to syncing upstream content to your fork with:
#
#     $ git fetch upstream
#
#     $ git checkout main
#
#     $ git merge upstream/main
#
# 5) Now, navigate to `coursework/student_folders` folder. Make a folder in here labeled by your name in all lowercase(i.e. `firstname_lastname`).
#
# 6) Copy your completed lecture notebooks (with all exercises in red finished) to your folder, adding your name to the file (e.g. `Lecture_1b_FirstnameLastname.ipynb`). This is what you will do for each week's lecture notebooks to get participation credit. Your lecture notebooks should have already been copies of my base lecture notebooks. **Never** run my base notebooks; always make a personal copy for yourself.
#
# 7) Copy the **Homework 1** notebook (this file) to your folder, adding your name (e.g. `vu_astr8070_s24_hw1_FirstnameLastname.ipynb`)
#
# 8) Complete the other problems listed below.
#
# 9) Submit your homework as follows (making sure that your added files are contained within your student folder):
#
#     $ git add vu_astr8070_s24_hw1_FirstnameLastname.ipynb
#
#     $ git commit -m "Uploaded Homework 1"
#
#     $ git push
#
# 10) Similarly add, commit, and push your completed lecture notebooks.
#
# 11) On your browser, navigate on GitHub to your fork of the course repository. You should see an option to initiate a `pull request` to merge your changes into the `main` repository. Your homework and lecture notebooks for the week are submitted when you initiate this pull request.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Consider a family with two children. Assume that the probability of females and males being born is equal, i.e. $p(F)=0.5$ and $p(M)=0.5$. Remember that "given" means your calculation is conditioned on some already fixed data or outcome.
#
# 1) What is the probability of one male and one female **GIVEN** that the first child is male.
#
# 2) What is the probability of two females **GIVEN** that at least one child is female.
#
# 3) What is the probability of two females **GIVEN** that the older child is female.
#
# You will find it easiest to answer these questions by sketching a "tree diagram" to visualize the options for the oldest child, and the branching options for the youngest child.
#
# Either write your solution as Markdown/Latex below, or paste in a scanned image of your handwritten solution.

# %% [markdown]
# ### Solution

# %% [markdown]
# This makedown is going to have a lot more detail for my better understanding!
#
# 1)  What is the probability of one male and one female GIVEN that the first child is male.
#
# Using Bayes' Theorem, we can find the probability of two children, one male and one female, given that the first child is male. Bayes' Theorem states that P(A|B) = P(B|A) * P(A) / P(B).
#
# What do we know first, we got to find the probabilities involved in the theorem
#
#     → P(M1|M1) = 1 (given that the first child is male, the probability that the first child is male is 1)
#     → P(M2|M1) = 0.5 (given that the first child is male, the probability that the second child is male is 0.5)
#     → P(F1|M1) = 0.5 (given that the first child is male, the probability that the first child is female is 0.5)
#     → P(F2|M1) = 0.5 (given that the first child is male, the probability that the second child is female is 0.5)
#     → P(M1) = 0.5 (the probability that the first child is male is 0.5)
#     → P(F1) = 0.5 (the probability that the first child is female is 0.5)
#
# We want to find P(M2|M1) * P(M1) / P(M1) which is equal to P(M2|M1). Therefore, the probability of one male and one female GIVEN that the first child is male is 0.5.
#
# <span style="color:red">You got the correct answer here, but sdome of the working does not make sense. For example, you state that the prob of the first child being female is 0.5 given that the first child is male. If we are given that the first child is male, then the prob that the first child is female must be zero! Treat the conditional statements as fixed data. I think a tree diagmra as recommended would've helped.</span>
#
#
#
# 2)  What is the probability of two females GIVEN that at least one child is female.
#
# To find this probability, we need to calculate the sum of the probabilities of the two cases:
#     1. Two females, or
#     2. one male and one female
#
# First, let's find the probability of the first case (two females):
#
#     → P(F1) = 0.5 (the probability that the first child is female is 0.5)
#     → P(F2|F1) = 1 (given that the first child is female, the probability that the second child is female is 1)
#     → P(F1|F1) = 1 (given that the first child is female, the probability that the first child is female is 1)
#
# Therefore, the probability of the first case is P(F1) * P(F2|F1) * P(F1|F1) = 0.5.
#
# Let's find the probability of the second case (one male and one female):
#
#     → P(F1) = 0.5 (the probability that the first child is female is 0.5)
#     → P(M2|F1) = 0.5 (given that the first child is female, the probability that the second child is male is 0.5)
#     → P(F1|F1) = 1 (given that the first child is female, the probability that the first child is female is 1)
#
# Therefore, the probability of the second case is P(F1) * P(M2|F1) * P(F1|F1) = 0.5.
#
# We find the sum of these probabilities, which is equal to the probability of two females GIVEN that at least one child is female:
#
#     → P(2F|at least 1F) = 0.5 + 0.5 = 1.
#
# <span style="color:red">Again, I can see what you were trying to do, but the "given" statements are data, and there are 3 possible ways of having at least one child female, i.e., 2F, MF, FM. Two females is one of these options, so the answer is 1/3.  -3 points.</span>
#
# 3) What is the probability of two females GIVEN that the older child is female.
#
# Calculate the sum of the probabilities of the two cases:
#
#     → The oldest child is female and the younger child is female, or
#     → The oldest child is female and the younger child is male.
#
# Find the probability of the first case (two females):
#
#     → P(F1) = 0.5 (the probability that the first child is female is 0.5)
#     → P(F2|F1) = 1 (given that the first child is female, the probability that the second child is female is 1)
#     → P(F1|F1) = 1 (given that the first child is female, the probability that the first child is female is 1)
#
# Therefore, the probability of the first case is P(F1) * P(F2|F1) * P(F1|F1) = 0.5.
#
# Find the probability of the second case (one male and one female):
#
#     → P(F1) = 0.5 (the probability that the first child is female is 0.5)
#     → P(M2|F1) = 0.5 (given that the first child is female, the probability that the second child is male is 0.5)
#     → P(F1|F1) = 1 (given that the first child is female, the probability that the first child is female is 1)
#
# Therefore, the probability of the second case is P(F1) * P(M2|F1) * P(F1|F1) = 0.5.
#
# The sum of these probabilities, which is equal to the probability of two females GIVEN that the older child is female:
#
#     → P(2F|oldest F) = 0.5 + 0.5 = 1
#
#
# <span style="color:red">Same problem again. If the older child is female, then there are two options for the second child, i.e., M or F. Two females would then have a prob of 1/2.  -3 points.</span>

# %% [markdown]
# ## Problem 3
#
# 1) Use `numpy` to draw $1000$ random samples from a uniform distribution between $0.1$ and $10$, and store these samples as $x$.
#
# 2) Use matplotlib to make a histogram of these samples. Try to make this as aesthetically pleasing as possible (within reason).
#
# 3) Compute the base-10 log of your array $x$, and store this as $y$.
#
# 4) Make another histogram for $y$. Using the equation to transform probability distributions in `Lecture_2`, write here what the theoretical pdf of $y$ is, and overplot it onto your histogram.
#
# 5) Compute the mean of $x$ and the mean of $y$. Now compute the median of $x$ and the median of $y$. You should note that the means are different, but the medians (as it is a cumulative statistic) are the same. The mean is affected by the scale of the sample values, but the median only depends on the ordering of the samples. Monotonic transformations (like taking the log) do not change the ordering of samples.

# %% [markdown]
# ### Solution

# %%
# import lib
import numpy as np
import matplotlib.pyplot as plt
x = np.random.uniform(0.1, 10, 1000)
mean_x = np.mean(x)
median_x = np.median(x)

# %%
print(f"Mean of x: {mean_x}")
print(f"Median of x: {median_x}")
# Out:
# Mean of x: 5.018747199253223
# Median of x: 4.892882248979075

# %%
plt.hist(x, bins=20, edgecolor='black', linewidth=1.2)
plt.title('Histogram of $1000$ Random Samples from a Uniform Distribution (0.1, 10)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()

# %%
y = np.log10(x)

# %%
# Compute the theoretical pdf of y
y_min, y_max = y.min(), y.max()
y_grid = np.linspace(y_min, y_max, 100)
f_y = (1/(10**-y_grid * np.log(10))) * np.exp(-10**-y_grid)

#f_y = np.exp(-10**y_grid) * (10**y_grid * np.log(10))

# Plot the histogram of y
plt.hist(y, bins=50, density=True, alpha=0.5, label='Histogram')

# Plot the theoretical pdf of y
plt.plot(y_grid, f_y, '-r', label='Theoretical pdf')

# Add labels and legend
plt.xlabel('y')
plt.ylabel('Probability density')
plt.legend()

# Show the plot
plt.show()
# Out:
# 0.9995032077089971

# %% [markdown]
# <span style="color:red">The pseudo-math you've written doesn't match your code for the pdf of y. The correct pdf is 10^y * ln (10) * p(x). Since p(x) is a uniform distribution between 0.1 and 10, p(x) = 1/(10-0.1), i.e., the pdf is normalized such that int_0.1^1 p(x)dx = 1. Let me know if you want to discuss this further, Kamara. -3 points.</span>

# %%
# Compute the mean of y
mean_y = np.mean(y)

# Compute the median of y
median_y = np.median(y)

print(f"Mean of y: ", mean_y)
print(f"Median of y:" , median_y)
print('Mean of y:', y_mean)
print('Median of y:', y_median)
# Out:
# Mean of y:  0.5778284636083774
# Median of y: 0.6895646417102421
# Mean of y: 1.5953641884159053
# Median of y: 1.7119182411936722

# %% [markdown]
# <span style="color:red">I can't see where y_mean and y_mediana re defined. But your answers for mean_y and median_y are correct. Now if you convert those numbers back into x values, you'll find that 10^median_y = median_x, while 10^mean_y does not equal mean_x. -2 points.</span>

# %% [markdown]
# I dont think that these values make sense to me which make me think that this is wrong
